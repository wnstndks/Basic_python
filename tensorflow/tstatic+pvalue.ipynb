# %%
import pandas as pd
data={
    '지각횟수':[1,2,3,4,5],
    '판매횟수':[8,7,6,4,5]
}
df=pd.DataFrame(data)

# %%
print(df.corr())

# %%
from scipy import stats

# 두 강사의 성적 데이터
강사1 = [71, 58, 92, 78, 71, 68, 67, 88, 88, 60, 80, 70, 68, 82, 78]
강사2 = [50, 65, 75, 91, 67, 39, 81, 68, 97, 86, 66, 60, 65, 55, 58]

# t-검정 수행
t_statistic, p_value = stats.ttest_ind(강사1, 강사2)

# p-value를 기준으로 유의수준 0.05에서 검정

if p_value < alpha:
    print("귀무가설을 기각합니다. 두 강사에 따른 성적의 평균은 다를 가능성이 있습니다.")
else:
    print("귀무가설을 채택합니다. 두 강사에 따른 성적의 평균은 같다고 할 수 있습니다.")
